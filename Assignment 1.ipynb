# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/hp/Downloads/healthcare_dataset.csv")

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age              Date of Admission  Billing Amount  \
# count  55500.000000                          55500    55500.000000
# mean      51.539459  2021-11-01 01:02:22.443243008    25539.316097
# min       13.000000            2019-05-08 00:00:00    -2008.492140
# 25%       35.000000            2020-07-28 00:00:00    13241.224652
# 50%       52.000000            2021-11-01 00:00:00    25538.069376
# 75%       68.000000            2023-02-03 00:00:00    37820.508436
# max       89.000000            2024-05-07 00:00:00    52764.276736
# std       19.602454                            NaN    14211.454431
#
#         Room Number                 Discharge Date  Length of Stay
# count  55500.000000                          55500    55500.000000
# mean     301.134829  2021-11-16 13:15:20.821621504       15.509009
# min      101.000000            2019-05-09 00:00:00        1.000000
# 25%      202.000000            2020-08-12 00:00:00        8.000000
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], kde=True, bins=30)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# * Symmetry: Most patients' ages are near the mean, with younger and older patients equally less frequent.
# * Majority near the mean: 68% are within 1 standard deviation, 95% within 2, and 99.7% within 3.
# * No skew: Neither young nor old patients dominate.
# * Balanced age representation: The hospital serves a wide range of ages, not skewed toward specific age groups.
# * Predictability: Age trends are easier to estimate.
# * No extreme outliers: Few very young or old patients

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Billing Amount'], kde=True, bins=30)
plt.title('Billing Amount Distribution')
plt.show()

# %% [markdown]
# * Symmetry: High and low bills are equally likely.
# * Predictable billing: 68% of bills are within 1 standard deviation of the mean.
# * Few outliers: Very high or low bills are rare.
# * No skew: The hospital doesn't often deal with extreme costs.
# * Balanced resource use: Costs are evenly distributed across patients

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df[['Age', 'Billing Amount', 'Room Number']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(6, 6))
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# * Balanced patient demographics with no gender bias.
# * No gender-specific trends in medical conditions or treatments.
# * Neutrality in services and resource use.
# * Equal access and opportunities for both genders

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Blood Type', order=df['Blood Type'].value_counts().index)
plt.title('Blood Type Distribution')
plt.show()

# %% [markdown]
# * Equal representation of all blood types.
# * A diverse patient population.
# * No treatment preference based on blood type.
# * Blood type is not a significant factor in patient care.

# %%
plt.figure(figsize=(10, 6))
df['Medical Condition'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Medical Conditions')
plt.show()

# %% [markdown]
# * Higher incidence of arthritis among patients.
#  * Need for more resources focused on arthritis treatment and management.
# * Possible risk factors contributing to arthritis in the population.
# * Emphasis on chronic condition management for arthritis.
# * Lower resource need for asthma, but vigilance in care is still important.
# * Potential for public health initiatives targeting arthritis awareness and prevention

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Admission Type', order=df['Admission Type'].value_counts().index)
plt.title('Admission Type Distribution')
plt.show()

# %% [markdown]
# * Focus on planned care and scheduled treatments.
# * Lower demand for emergency care, suggesting better overall community health.
# * Resource allocation may favor elective procedures.
# * Potentially higher patient satisfaction with scheduled care.
# * Possible concerns about wait times for elective procedures.
# * |Reflection of effective chronic disease management and preventive care.

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# %%
df['Length of Stay'] = (df['Discharge Date'] - df['Date of Admission']).dt.days
plt.figure(figsize=(10, 6))
sns.histplot(df['Length of Stay'], kde=True, bins=30)
plt.title('Length of Stay Distribution')
plt.show()

# %% [markdown]
# * Consistent treatment protocols across patients.
# * Predictable recovery times for specific conditions.
# * Better resource planning for bed availability.
# * Uniformity in patient care and outcomes.
# * Potential for benchmarking against other facilities

# %%
plt.figure(figsize=(12, 6))
df['Date of Admission'].dt.month.value_counts().sort_index().plot(kind='bar')
plt.title('Admissions per Month')
plt.show()

# %% [markdown]
# * Peak admission day on the 8th.
# * Possible scheduling preferences for that date.
# * Need for increased staffing and resources on the 8th.
# * Potential external factors influencing admissions.
# * Possible link to follow-up treatments after earlier visits

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Gender', y='Billing Amount')
plt.title('Billing Amount by Gender')
plt.show()

# %% [markdown]
# * Equal cost of care without gender bias.
# * Similar treatment needs for both genders.
# * Balanced resource use across genders.
# * Consistent healthcare practices in billing.
# * Equity in access to healthcare services

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Admission Type', y='Billing Amount')
plt.title('Billing Amount by Admission Type')
plt.show()

# %% [markdown]
# * Standardized pricing across admission types.
# * Similar resource utilization for each type.
# * Equity in care without financial disparities.
# * Possible misunderstanding about treatment levels based on cost.
# * Efficiency in management and billing processes.

# %%
plt.figure(figsize=(12, 6))
df['Doctor'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Doctors by Patient Count')
plt.show()

# %% [markdown]
# * Higher popularity for Michael Smith.
# * Possible specialization in high-demand services.
# * Effective marketing or referral networks for Michael.
# * Greater availability of appointments with Michael.
# * Need for improvement in Matthew Smith's practice or outreach

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# %%
print(df.describe(include='all'))
# Out:
#                Name           Age Gender Blood Type Medical Condition  \
# count         55500  55500.000000  55500      55500             55500
# unique        49992           NaN      2          8                 6
# top     DAvId muNoZ           NaN   Male         A-         Arthritis
# freq              3           NaN  27774       6969              9308
# mean            NaN     51.539459    NaN        NaN               NaN
# min             NaN     13.000000    NaN        NaN               NaN
# 25%             NaN     35.000000    NaN        NaN               NaN
# 50%             NaN     52.000000    NaN        NaN               NaN
# 75%             NaN     68.000000    NaN        NaN               NaN
# max             NaN     89.000000    NaN        NaN               NaN
# std             NaN     19.602454    NaN        NaN               NaN
#
#                     Date of Admission         Doctor   Hospital  \
# ...

# %%
correlation_matrix = df[['Age', 'Billing Amount']].corr()
print(correlation_matrix)
# Out:
#                      Age  Billing Amount
# Age             1.000000       -0.003832
# Billing Amount -0.003832        1.000000

# %% [markdown]
# * Weak Negative Correlation: Very little relationship between age and billing amount.
# * No Practical Significance: Age does not significantly influence billing amounts.
# * Independence of Variables: Age and billing are relatively independent; other factors likely affect billing.
# * Need for Further Investigation: Other variables may provide more insights into billing amount

# %% [markdown]
# ### Conclusion

# %% [markdown]
# * Univariate Analysis:
# * Demographics: Identifies primary age groups and balanced gender access to healthcare.
# * Billing Insights: Reveals average costs associated with conditions and treatments.
# * Admission Trends: Informs resource needs based on admission types.
# * Condition Prevalence: Highlights common medical conditions for targeted care.
# * Multivariate Analysis:
# * Variable Relationships: Weak correlation between age and billing; billing influenced by other factors.
# * Equitable Treatment: Similar billing for genders indicates fair resource allocation.
# * Comparative Costs: Helps identify cost differences across admission types.
# * High-Cost Areas: Average billing per condition indicates where to focus healthcare resources.
# * Provider Popularity: Variations in patient counts reveal provider effectiveness and areas for improvement.
